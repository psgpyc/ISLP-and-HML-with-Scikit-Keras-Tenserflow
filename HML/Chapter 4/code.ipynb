# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
m = 100 #no. of data points
X = np.random.rand(m,1)

# %%
y = 4 + 3 * X + np.random.randn(m, 1)

# %%
plt.scatter(X, y)

# %%
from sklearn.preprocessing import add_dummy_feature

# %%
Xd = add_dummy_feature(X)

# %%
theta_hat = np.linalg.inv(Xd.T @ Xd) @ Xd.T @ y

# %%
theta_hat
# Out:
# array([[4.21509616],
#        [2.54022677]])

# %% [markdown]
# Let us use the value of $\hat \theta$ to make the prediction

# %%
x_new = np.array([[0], [2]])

# %%
x_new = add_dummy_feature(x_in)

# %%
x_new
# Out:
# array([[1., 0.],
#        [1., 2.]])

# %%
y_pred = Xd @ theta_hat

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color="green")

# %% [markdown]
# Performaing linear regression using scikitlearn is straight forward

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([4.21509616])

# %%
lr.coef_
# Out:
# array([[2.54022677]])

# %%
np.log(0.9)
# Out:
# -0.10536051565782628

# %%
-np.log(0.1)
# Out:
# 2.3025850929940455

# %%
-np.log(0.96)
# Out:
# 0.040821994520255166
