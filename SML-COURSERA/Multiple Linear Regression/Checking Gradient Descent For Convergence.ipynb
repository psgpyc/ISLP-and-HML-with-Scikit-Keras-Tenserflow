# %% [markdown]
# ![image.png](attachment:236eb7c4-d57e-4797-badf-168c22040069.png)

# %% [markdown]
# ## Choosing an appropriate learning rate

# %% [markdown]
# **Identifying problem with Gradient Descent**
#
# - If the cost sometime is going up and sometime is going down. The $\alpha$ is probably too big.
# - If the gradient descent algorithm is taking longer than usual, then $\alpha$ is very small.
