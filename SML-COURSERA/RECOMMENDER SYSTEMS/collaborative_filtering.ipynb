# %% [markdown]
# In the previous example, we have the values for the features, what if we do not have the features but have already learned the parameters for the four users.

# %% [markdown]
# ## Collaborative Filtering

# %% [markdown]
# Given, $w^{(1)}, b^{(1)}  ,w^{(2)}, b^{(2)},........,w^{(n_u)}, b^{(n_u)} $
#
# to learn $x{(i)}$:
#     $J(x^{(i)})$ = $\frac{1}{2} \sum_{i=1}^{n_m}$$\frac{1}{2} \sum_{i:r(i,j)=1} (w^{(j)} \cdot x^{(i)} + b^{(j)} - y^{(i,j)})^2$ + $\frac{\lambda}{2} \sum_{i=1}^{n_m}\sum_{k=1}^{n} (w_k^{(j)})^2$

# %% [markdown]
# ## Where can we get the value for $W$ and $b$

# %% [markdown]
# We already have, our cost functions to learn the parameters $W$ and $b$ for all the users
#
#  $\frac{1}{2} \sum_{j=1}^{n_u}$$\frac{1}{2} \sum_{i:r(i,j)=1} (w^{(j)} \cdot x^{(i)} + b^{(j)} - y^{(i,j)})^2$ + $\frac{\lambda}{2}\sum_{j=1}^{n_u}\sum_{k=1}^{n} (w_k^{(j)})^2$

# %% [markdown]
# Now we have, a cost function to learn features for each movies.

# %% [markdown]
# ## Combining these:

# %% [markdown]
# $J(W, b, x)$ = $\frac{1}{2} \sum_{(i,j):r(i,j)=1} (w^{(j)} \cdot x^{(i)} + b^{(j)} - y^{(i,j)})^2$ + $\frac{\lambda}{2}\sum_{j=1}^{n_u}\sum_{k=1}^{n} (w_k^{(j)})^2$ + $\frac{\lambda}{2} \sum_{i=1}^{n_m}\sum_{k=1}^{n} (w_k^{(j)})^2$

# %% [markdown]
# ## Gradient Descent with the cost function

# %% [markdown]
# ![image.png](attachment:99773b0f-886d-4ced-8edb-05c415e71f95.png)
