# %% [markdown]
# ### What is Recommender System?
#
# Algorithm designed to suggest items to users based on their preferences, behaviour, or past interactions.  In below example, we are trying to predict movies to the users based on the ratings they have provided.
#
#
# Consider the below,
#
# <img src="attachment:ca68fbc3-26b9-457b-816f-9a9c7760a7ff.png" width="500">
#
#
# Now, consider the below, (? means the users has not rated the movie\)
#
# <img src="attachment:29e30fa2-d673-4895-975f-7dea772ce0dc.png" width="500">

# %% [markdown]
# ## Notations

# %% [markdown]
# $n_u \ = \ no. of users$
# $n_m \ = \ no. of movies$
# $r(i, j) \ = \ 1 \ if \ user \ j \ has \ rated \ movie \ i \ $
#
# $y^{(i,j)} = rating \ give \ by \ user \ j \ to \ movie \ i $
#
# &nbsp; This is only defined if $r(i,j) == 1$
#
# $n \ = \ no. \ of \ features $

# %% [markdown]
# In our case,
#
# $n_u = 4$
# $n_m = 5$
# $r(1,1) = 1$
# $r(3,1) = 0$
# $y^{(3,2)} = 4$

# %% [markdown]
# **Now if we introduce two features per data point like below:**
#
# <img src="attachment:8c8ce892-4693-48de-beea-d3b8bb25b9fe.png" width="100">
#
# Then,
#
# $n = 2$
